# %%
t=("pwskills","Asef",2,2.3,3+5j)

# %%
type(t)
# Out:
# tuple

# %%
t[0]
# Out:
# 'pwskills'

# %%
t[-3]
# Out:
# 2

# %%
print(t*2)
# Out:
# ('pwskills', 'Asef', 2, 2.3, (3+5j), 'pwskills', 'Asef', 2, 2.3, (3+5j))

# %%
s={1,2,3,4,5,5,4,3,2,1}

# %%
print(s)
# Out:
# {1, 2, 3, 4, 5}

# %%
s.add(126)

# %%
s
# Out:
# {1, 2, 3, 4, 5, 126}

# %%
s.pop()
# Out:
# 1

# %%
s.remove(3)

# %%
s
# Out:
# {2, 4, 5, 126}

# %%
s.add(1)

# %%
s
# Out:
# {1, 2, 4, 5, 126}

# %%
s.update("Asef")

# %%
s
# Out:
# {1, 126, 2, 4, 5, 'A', 'e', 'f', 's'}

# %%
s.update(['Asef','Data Science'])

# %%
s
# Out:
# {1, 126, 2, 4, 5, 'A', 'Asef', 'Data Science', 'e', 'f', 's'}

# %%
s1={"hiking","reading","coding"}
s2={"reading","traveling","music"}

# %%
 s1|s2
# Out:
# {'coding', 'hiking', 'music', 'reading', 'traveling'}

# %%
s1 &s2
# Out:
# {'reading'}

# %%
s1-s2
# Out:
# {'coding', 'hiking'}

# %%
s1^s2
# Out:
# {'coding', 'hiking', 'music', 'traveling'}

# %%
my_fs=frozenset(["Asef","Data Science","Machine Learning"])

# %%
print(my_fs)
# Out:
# frozenset({'Asef', 'Machine Learning', 'Data Science'})
