# %%
#ASCII
char="A"
ord(char) #ord=ordinal means the numerical order of the character
# Out:
# 65

# %%
chr(65) #character corresponding to the number
# Out:
# 'A'

# %%
'I'm a student'
# Out:
#   Cell In[3], line 1
#     'I'm a student'
#                   ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
"I'm a student"
# Out:
# "I'm a student"

# %%
"Hello"+" World"
# Out:
# 'Hello World'

# %%
string1="I am a good student"
string1[0:4]
# Out:
# 'I am'

# %%
string1[:-3]
# Out:
# 'I am a good stud'

# %%
string1[0:5:2]
# Out:
# 'Ia '

# %%
string1.replace("student","teacher")
# Out:
# 'I am a good teacher'

# %%
text="Hello World"
text.swapcase()
# Out:
# 'hELLO wORLD'

# %%
text.capitalize()
# Out:
# 'Hello world'

# %%
sentence="I am a student at BUET"
search_word="am"
if search_word in sentence:
    print("Present in the word")
else:
    print("Not present")
# Out:
# Present in the word

# %%
name=["Rayyan","Asef","Iztihad"]
sorted(name)
# Out:
# ['Asef', 'Iztihad', 'Rayyan']
