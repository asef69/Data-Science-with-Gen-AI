# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("https://raw.githubusercontent.com/pandas-dev/pandas/master/doc/data/titanic.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                                Heikkinen, Miss Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df1=df[["Name","Age","Sex"]][0:5]

# %%
df1
# Out:
#                                                 Name   Age     Sex
# 0                            Braund, Mr. Owen Harris  22.0    male
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0  female
# 2                              Heikkinen, Miss Laina  26.0  female
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0  female
# 4                           Allen, Mr. William Henry  35.0    male

# %%
df2=df[["Name","Age","Sex"]][5:10]

# %%
df2
# Out:
#                                                 Name   Age     Sex
# 5                                   Moran, Mr. James   NaN    male
# 6                            McCarthy, Mr. Timothy J  54.0    male
# 7                      Palsson, Master Gosta Leonard   2.0    male
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  27.0  female
# 9                Nasser, Mrs. Nicholas (Adele Achem)  14.0  female

# %%
pd.concat([df1,df2])
# Out:
#                                                 Name   Age     Sex
# 0                            Braund, Mr. Owen Harris  22.0    male
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0  female
# 2                              Heikkinen, Miss Laina  26.0  female
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0  female
# 4                           Allen, Mr. William Henry  35.0    male
# 5                                   Moran, Mr. James   NaN    male
# 6                            McCarthy, Mr. Timothy J  54.0    male
# 7                      Palsson, Master Gosta Leonard   2.0    male
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  27.0  female
# 9                Nasser, Mrs. Nicholas (Adele Achem)  14.0  female

# %%
pd.concat([df1,df2],axis=1)
# Out:
#                                                 Name   Age     Sex  \
# 0                            Braund, Mr. Owen Harris  22.0    male
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0  female
# 2                              Heikkinen, Miss Laina  26.0  female
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0  female
# 4                           Allen, Mr. William Henry  35.0    male
# 5                                                NaN   NaN     NaN
# 6                                                NaN   NaN     NaN
# 7                                                NaN   NaN     NaN
# 8                                                NaN   NaN     NaN
# 9                                                NaN   NaN     NaN
#
#                                                 Name   Age     Sex
# 0                                                NaN   NaN     NaN
# 1                                                NaN   NaN     NaN
# ...

# %%
df2.reset_index(drop=True,inplace=True)

# %%
df2
# Out:
#                                                 Name   Age     Sex
# 0                                   Moran, Mr. James   NaN    male
# 1                            McCarthy, Mr. Timothy J  54.0    male
# 2                      Palsson, Master Gosta Leonard   2.0    male
# 3  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  27.0  female
# 4                Nasser, Mrs. Nicholas (Adele Achem)  14.0  female

# %%
df3=pd.DataFrame(
    {
        "A":[1,2,3],
        "B":[4,5,6],
        "C":[7,8,9]
    }
)

# %%
df3
# Out:
#    A  B  C
# 0  1  4  7
# 1  2  5  8
# 2  3  6  9

# %%
df4=pd.DataFrame(
    {
        "A":[10,11,12],
        "B":[13,14,15],
        "C":[16,17,18]
    }
)

# %%
pd.merge(df3,df4,how='outer',on='A')
# Out:
#     A  B_x  C_x   B_y   C_y
# 0   1  4.0  7.0   NaN   NaN
# 1   2  5.0  8.0   NaN   NaN
# 2   3  6.0  9.0   NaN   NaN
# 3  10  NaN  NaN  13.0  16.0
# 4  11  NaN  NaN  14.0  17.0
# 5  12  NaN  NaN  15.0  18.0

# %%
pd.merge(df3,df4,how='left',on="A")
# Out:
#    A  B_x  C_x  B_y  C_y
# 0  1    4    7  NaN  NaN
# 1  2    5    8  NaN  NaN
# 2  3    6    9  NaN  NaN

# %%
pd.merge(df3,df4,how='cross')
# Out:
#    A_x  B_x  C_x  A_y  B_y  C_y
# 0    1    4    7   10   13   16
# 1    1    4    7   11   14   17
# 2    1    4    7   12   15   18
# 3    2    5    8   10   13   16
# 4    2    5    8   11   14   17
# 5    2    5    8   12   15   18
# 6    3    6    9   10   13   16
# 7    3    6    9   11   14   17
# 8    3    6    9   12   15   18

# %%
pd.merge(df3,df4,how='left',left_on='A', right_on='A')
# Out:
#    A  B_x  C_x  B_y  C_y
# 0  1    4    7  NaN  NaN
# 1  2    5    8  NaN  NaN
# 2  3    6    9  NaN  NaN

# %%
df3.join(df4,lsuffix='_left', rsuffix='_right')
# Out:
#    A_left  B_left  C_left  A_right  B_right  C_right
# 0       1       4       7       10       13       16
# 1       2       5       8       11       14       17
# 2       3       6       9       12       15       18

# %%
df3.join(df4,how='inner',lsuffix='_left', rsuffix='_right')
# Out:
#    A_left  B_left  C_left  A_right  B_right  C_right
# 0       1       4       7       10       13       16
# 1       2       5       8       11       14       17
# 2       3       6       9       12       15       18

# %%
df['Fair_new'] = df['Fare'].apply(lambda x: x*2)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                                Heikkinen, Miss Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
def convert(x):
    return x*1.5

# %%
df['Fair_new'] = df['Fare'].apply(convert)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                                Heikkinen, Miss Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
def fare_category(fare):
    if fare < 20:
        return 'Low'
    elif 20 <= fare < 50:
        return 'Medium'
    else:
        return 'High'

# %%
df['Fare_Category'] = df['Fare'].apply(fare_category)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                                Heikkinen, Miss Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df['Fare'].apply(fare_category)
# Out:
# 0         Low
# 1        High
# 2         Low
# 3        High
# 4         Low
#         ...
# 886       Low
# 887    Medium
# 888    Medium
# 889    Medium
# 890       Low
# Name: Fare, Length: 891, dtype: object

# %%
df['Fare_category']=df['Fare'].apply(fare_category)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                                Heikkinen, Miss Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...
