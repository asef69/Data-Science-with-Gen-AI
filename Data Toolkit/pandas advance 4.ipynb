# %%
import pandas as pd

# %%
df=pd.DataFrame({
    'Description': ['Apply Function', 'Lambda Function', 'User-defined Function'],
    'Purpose': [
        'To apply a function along an axis of the DataFrame or on values of Series.',
        'To create small anonymous functions at runtime.',
        'To define custom functions for specific operations.'
    ],
})

# %%
pd.set_option('display.max_colwidth',10000)

# %%
df
# Out:
#              Description  \
# 0         Apply Function
# 1        Lambda Function
# 2  User-defined Function
#
#                                                                       Purpose
# 0  To apply a function along an axis of the DataFrame or on values of Series.
# 1                             To create small anonymous functions at runtime.
# 2                         To define custom functions for specific operations.

# %%
pd.set_option('display.max_rows',10000)

# %%
df['Description']
# Out:
# 0           Apply Function
# 1          Lambda Function
# 2    User-defined Function
# Name: Description, dtype: object

# %%
df['Char_length']=df['Description'].apply(len)

# %%
df
# Out:
#              Description  \
# 0         Apply Function
# 1        Lambda Function
# 2  User-defined Function
#
#                                                                       Purpose  \
# 0  To apply a function along an axis of the DataFrame or on values of Series.
# 1                             To create small anonymous functions at runtime.
# 2                         To define custom functions for specific operations.
#
#    Char_length
# 0           14
# 1           15
# 2           21

# %%
df['Word Length']=df['Description'].apply(lambda x: len(x.split()))

# %%
df
# Out:
#              Description  \
# 0         Apply Function
# 1        Lambda Function
# 2  User-defined Function
#
#                                                                       Purpose  \
# 0  To apply a function along an axis of the DataFrame or on values of Series.
# 1                             To create small anonymous functions at runtime.
# 2                         To define custom functions for specific operations.
#
#    Char_length  Word Length
# 0           14            2
# 1           15            2
# 2           21            2

# %%
data={
    'text':['Data Science is an interdisciplinary field.',
            'It uses scientific methods, processes, algorithms and systems to extract knowledge and insights from structured and unstructured data.',
            'Data Science is related to data mining, machine learning and big data.'],
    'value':[10,20,30]        
}

# %%
a=pd.DataFrame(data)

# %%
a
# Out:
#                                                                                                                                      text  \
# 0                                                                                             Data Science is an interdisciplinary field.
# 1  It uses scientific methods, processes, algorithms and systems to extract knowledge and insights from structured and unstructured data.
# 2                                                                  Data Science is related to data mining, machine learning and big data.
#
#    value
# 0     10
# 1     20
# 2     30

# %%
a['text'].str.lower()
# Out:
# 0                                                                                               data science is an interdisciplinary field.
# 1    it uses scientific methods, processes, algorithms and systems to extract knowledge and insights from structured and unstructured data.
# 2                                                                    data science is related to data mining, machine learning and big data.
# Name: text, dtype: object

# %%
a['text_lower']=a['text'].str.lower()

# %%
a
# Out:
#                                                                                                                                      text  \
# 0                                                                                             Data Science is an interdisciplinary field.
# 1  It uses scientific methods, processes, algorithms and systems to extract knowledge and insights from structured and unstructured data.
# 2                                                                  Data Science is related to data mining, machine learning and big data.
#
#    value  \
# 0     10
# 1     20
# 2     30
#
#                                                                                                                                text_lower
# 0                                                                                             data science is an interdisciplinary field.
# ...

# %%
a['text'][0].startswith('Data')
# Out:
# True

# %%
df1={
    'Name':['Alice','Bob','Charlie','David'],
    'Age':[25,30,35,40],
    'City':['New York','Los Angeles','Chicago','Houston']
}

# %%
df1=pd.DataFrame(df1)

# %%
df1
# Out:
#       Name  Age         City
# 0    Alice   25     New York
# 1      Bob   30  Los Angeles
# 2  Charlie   35      Chicago
# 3    David   40      Houston

# %%
df2=pd.DataFrame({
'a':[1,2,3,4],
'b':[5,6,7,8],
'c':[9,10,11,12]
})

# %%
df2
# Out:
#    a  b   c
# 0  1  5   9
# 1  2  6  10
# 2  3  7  11
# 3  4  8  12

# %%
df2.a.sum()
# Out:
# np.int64(10)

# %%
df2.rolling(window=2).mean()
# Out:
#      a    b     c
# 0  NaN  NaN   NaN
# 1  1.5  5.5   9.5
# 2  2.5  6.5  10.5
# 3  3.5  7.5  11.5

# %%
df2['a'].astype(int)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# Name: a, dtype: int64

# %%
import numpy as np

# %%
np.random.choice([1,2,3,4,5], size=10)
# Out:
# array([2, 1, 1, 2, 2, 3, 3, 5, 2, 5])

# %%
df2['random_choice']=np.random.choice([1,2,3,4,5], size=len(df2))

# %%
df2.groupby('random_choice')

# %%
df2
# Out:
#    a  b   c  random_choice
# 0  1  5   9              5
# 1  2  6  10              2
# 2  3  7  11              2
# 3  4  8  12              1

# %%
date_1=pd.DataFrame({
'date':['2023-01-01','2023-02-01','2023-03-01']
})
date_1['date']=pd.to_datetime(date_1['date'])
date_1['date'].dt.month
# Out:
# 0    1
# 1    2
# 2    3
# Name: date, dtype: int32

# %%
date_1
# Out:
#         date
# 0 2023-01-01
# 1 2023-02-01
# 2 2023-03-01

# %%
date_1['updated_date']=date_1['date'] + pd.DateOffset(months=3)

# %%
date_1
# Out:
#         date updated_date
# 0 2023-01-01   2023-04-01
# 1 2023-02-01   2023-05-01
# 2 2023-03-01   2023-06-01

# %%
date_1['month_after_adding']=date_1['updated_date'].dt.month

# %%
date_1
# Out:
#         date updated_date  month_after_adding
# 0 2023-01-01   2023-04-01                   4
# 1 2023-02-01   2023-05-01                   5
# 2 2023-03-01   2023-06-01                   6

# %%
pd.date_range(start='2023-01-01', end='2025-09-21', freq='h')
# Out:
# DatetimeIndex(['2023-01-01 00:00:00', '2023-01-01 01:00:00',
#                '2023-01-01 02:00:00', '2023-01-01 03:00:00',
#                '2023-01-01 04:00:00', '2023-01-01 05:00:00',
#                '2023-01-01 06:00:00', '2023-01-01 07:00:00',
#                '2023-01-01 08:00:00', '2023-01-01 09:00:00',
#                ...
#                '2025-09-20 15:00:00', '2025-09-20 16:00:00',
#                '2025-09-20 17:00:00', '2025-09-20 18:00:00',
#                '2025-09-20 19:00:00', '2025-09-20 20:00:00',
#                '2025-09-20 21:00:00', '2025-09-20 22:00:00',
#                '2025-09-20 23:00:00', '2025-09-21 00:00:00'],
#               dtype='datetime64[ns]', length=23857, freq='h')

# %%
pd.Timestamp.now()
# Out:
# Timestamp('2026-01-28 08:49:45.299245')

# %%
start=pd.Timestamp.now()

for i in range(1000000):
    a=i*i

end=pd.Timestamp.now()
end - start
# Out:
# Timedelta('0 days 00:00:00.083588')

# %%
import time
start=time.perf_counter()
for i in range(1000000):
    a=i*i

end=time.perf_counter()
end - start
# Out:
# 0.08482130000629695

# %%
pd.Timestamp.now()-pd.DateOffset(days=7)
# Out:
# Timestamp('2026-01-21 08:49:45.512836')

# %%
from datetime import datetime, timedelta
date="2026-01-28"
date_object=datetime.strptime(date, '%Y-%m-%d')
date_object - timedelta(days=7)
# Out:
# datetime.datetime(2026, 1, 21, 0, 0)

# %%
pip install yfinance
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import yfinance as yf

# %%
yf.download('GOOG',start='2023-01-01', end='2025-11-28', interval='1mo')
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price            Close        High         Low        Open     Volume
# Ticker            GOOG        GOOG        GOOG        GOOG       GOOG
# Date
# 2023-01-01   99.126534  100.823803   84.932985   89.161274  526178100
# 2023-02-01   89.627785  108.009913   88.198502   98.997506  754400500
# 2023-03-01  103.225800  106.709672   89.101728   89.488831  725477100
# 2023-04-01  107.414375  108.813875  101.617846  101.905688  461670700
# 2023-05-01  122.451614  126.104220  103.722083  106.918114  620361600
# 2023-06-01  120.069458  128.585587  116.039684  122.580623  521440000
# 2023-07-01  132.119080  133.071940  114.967720  119.424292  525480300
# 2023-08-01  136.327515  137.369686  126.054558  129.880856  463504700
# 2023-09-01  130.868469  138.888306  127.235712  137.399472  389639800
# 2023-10-01  124.367226  141.320078  120.555808  131.171190  514900900
# ...

# %%
#plotting functions in pandas
d=pd.Series([1,3,2,4,6,5,8,7])

# %%
pip install matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt
d.plot()
# Out:
# Matplotlib is building the font cache; this may take a moment.
# <Axes: >

# %%
d=pd.Series({
    '2023-01-01': 10,
    '2023-02-01': 15,
    '2023-03-01': 7,
    '2023-04-01': 12,
    '2023-05-01': 20
})

# %%
d.plot()
# Out:
# <Axes: >

# %%
d['2023-06-01']=18
d.plot()
# Out:
# <Axes: >
