# %%
import pandas as pd

# %%
pd.DataFrame({
    'Description': ['Apply Function', 'Lambda Function', 'User-defined Function'],
    'Purpose': [
        'To apply a function along an axis of the DataFrame or on values of Series.',
        'To create small anonymous functions at runtime.',
        'To define custom functions for specific operations.'
    ],
})
# Out:
#              Description                                            Purpose
# 0         Apply Function  To apply a function along an axis of the DataF...
# 1        Lambda Function    To create small anonymous functions at runtime.
# 2  User-defined Function  To define custom functions for specific operat...
