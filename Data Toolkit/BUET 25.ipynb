# %%
import pandas as pd

# %%
df = pd.read_excel('E:\PW skills\Data Toolkit\Converted_Results.xlsx')
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\P'
# <>:1: SyntaxWarning: invalid escape sequence '\P'
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_18780\2618156870.py:1: SyntaxWarning: invalid escape sequence '\P'
#   df = pd.read_excel('E:\PW skills\Data Toolkit\Converted_Results.xlsx')

# %%
df
# Out:
#       rollNo                       name  merit  \
# 0      50002         MD. SADIQUR RAHMAN    315
# 1      50023            MD. AQUIB AZMAL     15
# 2      50042           FARHAN BIN HASAN    251
# 3      50049           MD. MOSTAK NADIM    915
# 4      50051       SHAMILA WAFIQA HAQUE     17
# ...      ...                        ...    ...
# 1243   90977      ABONTIKA MONDAL ARTHI   1102
# 1244   90980     KASHFI BEENTE ABDULLAH    758
# 1245   90987   PROGGYAN MALLICK SHIRSHO    955
# 1246   90989        ABDUHU RUHUL BASHIR    798
# 1247   90990  MD. TASHFIQUL ISLAM RAJIN   1050
#
#                                  department
# 0       Electrical & Electronic Engineering
# 1       Electrical & Electronic Engineering
# 2            Computer Science & Engineering
# 3                      Chemical Engineering
# 4       Electrical & Electronic Engineering
# ...                                     ...
# 1243  Materials & Metallurgical Engineering
# ...

# %%
df['department']=='Computer Science & Engineering'
# Out:
# 0       False
# 1       False
# 2        True
# 3       False
# 4       False
#         ...
# 1243    False
# 1244    False
# 1245    False
# 1246    False
# 1247    False
# Name: department, Length: 1248, dtype: bool

# %%
df[df['department']=='Computer Science & Engineering'].name
# Out:
# 2            FARHAN BIN HASAN
# 6              SHAFQAT NAVEED
# 8            MD. AHSANUL DAUD
# 17                 ERIN JAHAN
# 22              JOYEETA MITRA
#                 ...
# 1193    MUHAMMAD NAZMUS SAQIB
# 1199    ARIJET SARDAR SWAPNIL
# 1210        ARSHIA ARMIN JHIL
# 1229       MD. SHAHRIAR SIFAT
# 1235              ARIBA IBNAT
# Name: name, Length: 181, dtype: object

# %%
result = df[df['department']=='Computer Science & Engineering'].reset_index(drop=True)
result=result.sort_values(by='merit')

result.insert(0, 'Serial.No', range(1, len(result) + 1))

# %%
result
# Out:
#      Serial.No  rollNo                      name  merit  \
# 93           1   54821    MD. RADHWAN RIDVI AKIF      1
# 165          2   59178            ADIB AL-MUKSIT      2
# 102          3   55435  ANANTO SHAHRIAR TALUKDAR      3
# 99           4   55228            SHADMAN SHAHAB      4
# 11           5   50508          S. M. AFIF IQBAL      5
# ..         ...     ...                       ...    ...
# 39         177   52150        S. M. ZARIF FAIYAZ    384
# 7          178   50272   MD. JAHIDUL ISLAM JIHAD    385
# 32         179   51906          MD.ABIDUR RAHMAN    386
# 43         180   52293    MD. AZIZUL ISLAM TALHA    389
# 163        181   59093             ADITYA SINGHA    508
#
#                          department
# 93   Computer Science & Engineering
# 165  Computer Science & Engineering
# 102  Computer Science & Engineering
# 99   Computer Science & Engineering
# 11   Computer Science & Engineering
# ..                              ...
# ...

# %%
result.to_excel('E:\PW skills\Data Toolkit\CSE_Department_Results.xlsx', index=False)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\P'
# <>:1: SyntaxWarning: invalid escape sequence '\P'
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_18780\500668669.py:1: SyntaxWarning: invalid escape sequence '\P'
#   result.to_excel('E:\PW skills\Data Toolkit\CSE_Department_Results.xlsx', index=False)

# %%
result[result['Serial.No']==84].name
# Out:
# 28    PRAMIT BISWAS
# Name: name, dtype: object

# %%
result.to_excel(r'E:\PW skills\Data Toolkit\CSE_Department_Results.xlsx', index=False)
