# %%
number=[1,2,3,4,5,3+4j,True,"asef"]
print(number[::-1])
type(number)
# Out:
# ['asef', True, (3+4j), 5, 4, 3, 2, 1]
# list

# %%
a="asef"
print(a[::-1])
# Out:
# fesa

# %%
#mutability
number[6]=True
print(number)
number[7]="Kazi Asef Kabir"
print(number)
# Out:
# [1, 2, 3, 4, 5, (3+4j), True, 'Kabir']
# [1, 2, 3, 4, 5, (3+4j), True, 'Kazi Asef Kabir']

# %%
b="pwskills"
b
# Out:
# 'pwskills'

# %%
b[0]="I" #string is immutable
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 b[0]="I"
#
# TypeError: 'str' object does not support item assignment
